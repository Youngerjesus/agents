# %%
# %pip install anthropic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /Users/jeongmin/Library/Python/3.9/lib/python/site-packages (0.42.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Python/3.9/site-packages (from anthropic) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jeongmin/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Python/3.9/site-packages (from anthropic) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/jeongmin/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Python/3.9/site-packages (from anthropic) (2.7.1)
# Requirement already satisfied: sniffio in /Library/Python/3.9/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Library/Python/3.9/site-packages (from anthropic) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /Library/Python/3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Library/Python/3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (1.2.1)
# Requirement already satisfied: certifi in /Library/Python/3.9/site-packages (from httpx<1,>=0.23.0->anthropic) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Library/Python/3.9/site-packages (from httpx<1,>=0.23.0->anthropic) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Python/3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Python/3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Library/Python/3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.18.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from anthropic import Anthropic
from dotenv import load_dotenv
import os

load_dotenv()

client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

def llm_call(prompt: str) -> str:
    response = client.messages.create(
        model="claude-3-5-sonnet-20241022",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=4096,
    )
    return response.content[0].text

def extract_xml(response: str, tag: str) -> str:
    start_tag = f"<{tag}>"
    end_tag = f"</{tag}>"
    start_index = response.find(start_tag)
    end_index = response.find(end_tag, start_index)
    return response[start_index:end_index+len(end_tag)]

# %%
from typing import List, Dict, Optional

def parse_tasks(tasks_xml: str) -> List[Dict]:
    """Parse XML tasks into a list of task dictionaries."""
    tasks = []
    current_task = {}
    
    for line in tasks_xml.split('\n'):
        line = line.strip()
        if not line:
            continue
            
        if line.startswith("<task>"):
            current_task = {}
        elif line.startswith("<type>"):
            current_task["type"] = line[6:-7].strip()
        elif line.startswith("<description>"):
            current_task["description"] = line[12:-13].strip()
        elif line.startswith("</task>"):
            if "description" in current_task:
                if "type" not in current_task:
                    current_task["type"] = "default"
                tasks.append(current_task)
    
    return tasks


class FlexibleOrchestrator:
    """Break down tasks and run them in parallel using worker LLMs."""
    
    def __init__(
        self,
        orchestrator_prompt: str,
        worker_prompt: str,
    ):
        """Initialize with prompt templates."""
        self.orchestrator_prompt = orchestrator_prompt
        self.worker_prompt = worker_prompt

    def _format_prompt(self, template: str, **kwargs) -> str:
        """Format a prompt template with variables."""
        try:
            return template.format(**kwargs)
        except KeyError as e:
            raise ValueError(f"Missing required prompt variable: {e}")

    def process(self, task: str, context: Optional[Dict] = None) -> Dict:
        """Process task by breaking it down and running subtasks in parallel."""
        context = context or {}
        
        # Step 1: Get orchestrator response
        orchestrator_input = self._format_prompt(
            self.orchestrator_prompt,
            task=task,
            **context
        )
        
        orchestrator_response = llm_call(orchestrator_input)
        
        # Parse orchestrator response
        analysis = extract_xml(orchestrator_response, "analysis")
        tasks_xml = extract_xml(orchestrator_response, "tasks")
        tasks = parse_tasks(tasks_xml)
        
        print("\n=== ORCHESTRATOR OUTPUT ===")
        print(f"\nANALYSIS:\n{analysis}")
        print(f"\nTASKS:\n{tasks}")
        
        # Step 2: Process each task
        worker_results = []
        for task_info in tasks:
            worker_input = self._format_prompt(
                self.worker_prompt,
                original_task=task,
                task_type=task_info['type'],
                task_description=task_info['description'],
                **context
            )
            
            worker_response = llm_call(worker_input)
            result = extract_xml(worker_response, "response")
            
            worker_results.append({
                "type": task_info["type"],
                "description": task_info["description"],
                "result": result
            })
            
            print(f"\n=== WORKER RESULT ({task_info['type']}) ===\n{result}\n")
        
        return {
            "analysis": analysis,
            "worker_results": worker_results,
        }

# %%
ORCHESTRATOR_PROMPT = """
Analyze this task and break it down into 2-3 distinct approaches:

Task: {task}

Return your response in this format:

<analysis>
Explain your understanding of the task and which variations would be valuable.
Focus on how each approach serves different aspects of the task.
</analysis>

<tasks>
    <task>
    <type>formal</type>
    <description>Write a precise, technical version that emphasizes specifications</description>
    </task>
    <task>
    <type>conversational</type>
    <description>Write an engaging, friendly version that connects with readers</description>
    </task>
</tasks>
"""

WORKER_PROMPT = """
Generate content based on:
Task: {original_task}
Style: {task_type}
Guidelines: {task_description}

Return your response in this format:

<response>
Your content here, maintaining the specified style and fully addressing requirements.
</response>
"""

orchestrator = FlexibleOrchestrator(
    orchestrator_prompt=ORCHESTRATOR_PROMPT,
    worker_prompt=WORKER_PROMPT,
)

results = orchestrator.process(
    task="Write a product description for a new eco-friendly water bottle",
    context={
        "target_audience": "environmentally conscious millennials",
        "key_features": ["plastic-free", "insulated", "lifetime warranty"]
    }
)
# Out:
# === ORCHESTRATOR OUTPUT ===
#
# ANALYSIS:
# <analysis>
# The task requires creating marketing copy for an eco-friendly water bottle, which presents an opportunity to approach it from multiple angles given the dual nature of the product: its functional purpose (hydration) and its environmental benefits. The key variations would serve different audience needs and purchasing motivations.
#
# A technical approach would appeal to detail-oriented consumers who make purchasing decisions based on specifications, materials, and concrete environmental impact metrics. This serves the "eco-friendly" aspect through verifiable claims and specific materials information.
#
# A lifestyle-focused approach would connect with environmentally conscious consumers who are motivated by emotional benefits and personal impact. This serves both the practical usage aspect and environmental messaging through relatable scenarios and benefits-oriented language.
# </analysis>
#
# TASKS:
# [{'type': 'formal', 'description': '>Create a specification-focused description highlighting exact materials, capacity, environmental impact metrics, and technical features. Include precise measurements, recycled material percentages, and durability statistics.<'}, {'type': 'conversational', 'description': '>Develop a narrative-style description that emphasizes lifestyle benefits, environmental impact through storytelling, and emotional connection to sustainability. Focus on daily use scenarios and personal environmental contribution.<'}]
#
# === WORKER RESULT (formal) ===
# <response>
# The EcoVessel Pro-Grade Sustainable Water Bottle
#
# Technical Specifications:
# • Capacity: 750ml (25.4 fl oz)
# • Dimensions: 27.5cm H x 7.6cm D (10.8" x 3")
# • Weight: 295g (10.4 oz)
#
# Construction:
# Engineered from 90% post-consumer recycled 18/8 food-grade stainless steel, the EcoVessel features a double-wall vacuum-sealed construction maintaining beverage temperature for 24 hours cold/12 hours hot (±2°C variance). The exterior coating utilizes VOC-free powder coating derived from natural minerals.
#
# Environmental Impact:
# • Carbon footprint reduction: 75% compared to virgin steel production
# • Water conservation: Manufacturing process uses 65% less water than conventional bottles
# • End-of-life recyclability: 100% recyclable components
# • Estimated plastic bottle replacement: 1,460 single-use bottles annually
#
# Technical Features:
# • Triple-seal technology with food-grade silicone gasket
# • Leak-proof rating: IPX7 (submersible to 1m)
# • Impact resistance: Tested to withstand drops from 2m onto concrete
# • BPA, BPS, and phthalate-free construction
# • Antimicrobial-treated mouthpiece (99.9% bacterial reduction)
# • Pressure-release safety valve
# • Non-slip base with 2mm elevation for condensation management
#
# Durability Metrics:
# • Operational lifespan: 10+ years under normal use
# • Thermal efficiency retention: 95% after 500 wash cycles
# • Scratch resistance: 8H on Mohs hardness scale
# • UV degradation resistance: 2,000 hours accelerated testing
# </response>
#
#
# === WORKER RESULT (conversational) ===
# <response>
# Hey there, fellow earth-conscious friend! Let me tell you about your new favorite companion in the journey toward a greener planet - the AquaEco Lifestyle Bottle.
#
# Picture this: It's early morning, and you're getting ready for another busy day. Your AquaEco is there, gleaming on your kitchen counter, ready to join your daily adventures. Made from recycled stainless steel that once had a completely different life (how cool is that?), this bottle isn't just another container - it's your personal statement against single-use plastic.
#
# You know that guilty feeling when you have to grab a plastic water bottle at the store? Kiss it goodbye! Your AquaEco holds a generous 24 ounces of your favorite beverage, keeping it cold for 24 hours or hot for 12. That means your morning coffee stays toasty during those long meetings, and your water stays refreshingly cool during your afternoon workout.
#
# But here's the really awesome part - every time you refill your AquaEco, you're saying "no thanks" to roughly 167 single-use plastic bottles per year. Think about that for a second... that's like saving a small army of plastic bottles from ending up in our oceans! The bottle's sleek, minimalist design isn't just about looking good (though it totally does) - it's about making sustainable choices feel natural and effortless in your daily life.
#
# We've included some thoughtful touches that'll make you smile: a leak-proof cap that you can operate with one hand, a comfortable carry loop made from recycled climbing rope, and measurement markers on the inside to help you track your hydration goals. Plus, the wide mouth means you can easily add ice cubes or give it a thorough cleaning.
#
# Whether you're hitting the gym, heading to the office, or embarking on a weekend adventure, your AquaEco is ready to help you stay hydrated while keeping our planet a little bit cleaner. Because let's face it - saving the world should be refreshing, right?
#
# Ready to make every sip count? Your new sustainable sidekick awaits!
# </response>
